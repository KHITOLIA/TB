# %%
# Q1 : reverse my given list without using any in built function and slicing
# artist = ['Jubin', 'Karan','Arijit', 'Honey', 'Sonu']

# %%
artist = ['Jubin','karan','Arijit','Honey','Sonu']

n = len(artist)

for i in range(n // 2):

    artist[i], artist[n - 1 - i] = artist[n - 1 - i], artist[i]

print(artist)
# Out:
# ['Sonu', 'Honey', 'Arijit', 'karan', 'Jubin']

# %%
a = []
for i in range(len(artist)):
  print(artist[i])
# Out:
# Sonu
# Honey
# Arijit
# karan
# Jubin

# %%
for i in range(len(artist), -1, -1):
  print(artist[-i])
# Out:
# Sonu
# Honey
# Arijit
# karan
# Jubin
# Sonu

# %%
artist[::-1]
# Out:
# ['Jubin', 'karan', 'Arijit', 'Honey', 'Sonu']

# %%
s = 'train'
s[::-1]
# Out:
# 'niart'

# %%
l = [1, 2, 2, 2, 3, 3, 4, 5, 9, 9]
# Q2 : find the unique items from the above list

# %%
a = []
for i in l:
  if i not in a:
    a.append(i)
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 9

# %%
a
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
number = int(input("enter the number = "))
b = 2
r = number - (number//b)*b
if r == 0:
  print("Even Number")
else:
  print("odd")
# Out:
# enter the number = 98
# Even Number

# %%
l = [1, 4, 5, 5, 7, 2, 2]
a = []
for i in l:
  if i not in a:
    a.append(i)

# %%
a
# Out:
# [1, 4, 5, 7, 2]

# %%
for i in a:
  count = 0
  for j in l:
    if i == j:
      count = count + 1
      print(i, count)
# Out:
# 1 1
# 4 1
# 5 1
# 5 2
# 7 1
# 2 1
# 2 2

# %%
s = 'The quick fox jumps over the box'
s = s.lower()
a = []
for i in s:
  if i not in a:
    a.append(i)
for i in a:
  print(f'count of {i} is {s.count(i)}')
# Out:
# count of t is 2
# count of h is 2
# count of e is 3
# count of   is 6
# count of q is 1
# count of u is 2
# count of i is 1
# count of c is 1
# count of k is 1
# count of f is 1
# count of o is 3
# count of x is 2
# count of j is 1
# count of m is 1
# count of p is 1
# count of s is 1
# count of v is 1
# count of r is 1
# count of b is 1

# %%
a
# Out:
# ['t',
#  'h',
#  'e',
#  ' ',
#  'q',
#  'u',
#  'i',
#  'c',
#  'k',
#  'f',
#  'o',
#  'x',
#  'j',
#  'm',
#  'p',
#  's',
#  'v',
#  'r',
#  'b']

# %%
1%10
# Out:
# 1

# %%
0%10
# Out:
# 0

# %%
1//10
# Out:
# 0

# %%
n = int(input("enter the number to reverse = "))
# 4321
digit = 0
j = int(input("enter the number = "))
for i in range(len(str(n))):
  r = n%10
  n = n//10
  digit = digit + r*j
  j = j//10
# Out:
# enter the number to reverse = 12345
# enter the number = 10000

# %%
digit
# Out:
# 54321

# %%
l1 = [1, 2, 4, 4, 4, 2, 5, 5, 5, 5]
l2 = [1, 4, 4, 5, 5]
l = []
for i in l2:
  for j in l1:
    if i == j:
      if i not in l:
        l.append(i)

# %%
l
# Out:
# [1, 4, 5]

# %%
l = []
a = []
n = 12222334431111
for i in str(n):
  if i not in l:
    l.append(i)
    a.append((int(i), str(n).count(i)))

# %%
a
# Out:
# [(1, 5), (2, 4), (3, 3), (4, 2)]

# %%
# sorted(a, reverse=True)

# %%
a = 10
while a > 5:
  print(a)
  print("training basket")
  a = a -1
# Out:
# 10
# training basket
# 9
# training basket
# 8
# training basket
# 7
# training basket
# 6
# training basket

# %%
a
# Out:
# 4

# %%
# import time
while True:
  passs_word = input('enter your password please')
  if passs_word == 'tushar':
    print("authenticated")
    break
  else:
    print("try again")
    # time.sleep(10)
# Out:
# enter your password pleasewerwerwer
# try again
# enter your password pleasetushar
# authenticated

# %%
s = 'training'
for i in s:
  print(i)
# Out:
# t
# r
# a
# i
# n
# i
# n
# g

# %%
i = 0
while True:
  print(s[i])
  i = i + 1
  if i == len(s):
    break
# Out:
# t
# r
# a
# i
# n
# i
# n
# g

# %%
a = 's'
chr(ord(a) - 32)
# Out:
# 'S'

# %%
a = 'DaTa ScIEnce'
a.swapcase()
# Out:
# 'dAtA sCieNCE'

# %%
s = ''
for i in a:
  if i.isupper():
    print(" ")
    continue
    print(chr(ord(i) + 32))
    s = s + chr(ord(i) + 32)
  elif i.islower():
    print(" ")
    print(chr(ord(i) - 32))
    s = s + chr(ord(i) - 32)
  elif i == ' ':
    s  = s + ' '
# Out:
#
#
# A
#
#
# A
#
#
# C
#
#
#
# N
#
# C
#
# E

# %%
s
# Out:
# 'AA CNCE'
