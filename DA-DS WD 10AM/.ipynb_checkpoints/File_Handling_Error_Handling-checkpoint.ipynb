# %%
# error handling

# %%
def divider(a,b):
    return a/b

# %%
divider(3, 6)
# Out:
# 0.5

# %%
divider(6, 2)
# Out:
# 3.0

# %%
divider(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 divider(10, 0)
#
# Cell In[2], line 2, in divider(a, b)
#       1 def divider(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
def divider(a, b):
    try:
        return a/b
    except ZeroDivisionError:
        print("not divisible by zero")

# %%
divider(6, 0)
# Out:
# not divisible by zero

# %%
n = int(input("enter the number"))
# Out:
# enter the number isdsa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 n = int(input("enter the number"))
#
# ValueError: invalid literal for int() with base 10: 'isdsa'

# %%
def divider(a, b):
    try:
        return a/b
    except Exception as e:
        print(e)
    finally:
        b = int(input("enter the value = "))
        return a/b

# %%
divider(6, '3')
# Out:
# unsupported operand type(s) for /: 'int' and 'str'
# enter the value =  3
# 2.0

# %%
7/'ere'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 7/'ere'
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# # File Handling

# %%
file = open('ml.txt', 'r')

# %%
file
# Out:
# <_io.TextIOWrapper name='ml.txt' mode='r' encoding='cp1252'>

# %%
open?
# Out:
# Signature:
# open(
#     file,
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None,
# )
# Docstring:
# Open file and return a stream.  Raise OSError upon failure.
#
# file is either a text or byte string giving the name (and the path
# if the file isn't in the current working directory) of the file to
# be opened or an integer file descriptor of the file to be
# wrapped. (If a file descriptor is given, it is closed when the
# returned I/O object is closed, unless closefd is set to False.)
#
# mode is an optional string that specifies the mode in which the file
# is opened. It defaults to 'r' which means open for reading in text
# mode.  Other common values are 'w' for writing (truncating the file if
# it already exists), 'x' for creating and writing to a new file, and
# 'a' for appending (which on some Unix systems, means that all writes
# ...

# %%
file.read()
# Out:
# ''

# %%
file.read()
# Out:
# ''

# %%
file.seek(0)
# Out:
# 0

# %%
len(file.read())
# Out:
# 69

# %%
len(a)
# Out:
# 69

# %%
file.seek(0)
# Out:
# 0

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
file = open('ml.txt', 'r')

# %%
file.read()
# Out:
# 'Hello World\nMachine learning\nDeep Learning\nTransformers\nNLP\nAi Agents'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readline()
# Out:
# 'Hello World\n'

# %%
file.readline()
# Out:
# 'Machine learning\n'

# %%
file.readline()
# Out:
# 'Deep Learning\n'

# %%
file.readline()
# Out:
# 'Transformers\n'

# %%
file.readline()
# Out:
# 'NLP\n'

# %%
file.readline()
# Out:
# 'Ai Agents'

# %%
file.readline()
# Out:
# ''

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Hello World\n',
#  'Machine learning\n',
#  'Deep Learning\n',
#  'Transformers\n',
#  'NLP\n',
#  'Ai Agents']

# %%
# write the backend code for this readlines method

# %%
file.seek(0)
# Out:
# 0

# %%
a = file.read()

# %%
file.seek(0)
# Out:
# 0

# %%
l = []
l.append(file.readline())

# %%
l
# Out:
# ['Hello World\n',
#  'Machine learning\n',
#  'Deep Learning\n',
#  'Transformers\n',
#  'NLP\n',
#  'Ai Agents']

# %%
l.append(file.readline())

# %%
a.split("\n")
# Out:
# ['Hello World',
#  'Machine learning',
#  'Deep Learning',
#  'Transformers',
#  'NLP',
#  'Ai Agents']

# %%
file.close()

# %%
file = open('ml.txt', 'a')

# %%
file.write("\nBurger King1")
# Out:
# 13

# %%
file.close()

# %%
file = open('ml.txt', 'r')
file.read()
# Out:
# 'Burger KingBurger King1\nBurger King1'

# %%
st = ''' Understanding the Core Concept of Machine LearningMachine learning is a subfield of artificial intelligence (AI) that uses algorithms to enable computers to learn from and make decisions or predictions based on data, without being explicitly programmed. 
The process involves training an algorithm on a large dataset to create a model, which can then be used to identify patterns and make predictions on new, unseen data. 
Common applications include product recommendations, fraud detection, and medical image analysis.  '''

# %%
# write the st in the file whenever you get a full stop
# find the number of lines generated

# %%
d = {
    'a' : 'laptop',
    'b' : 'smartphone',
    'c' : 'landline',
    'd' : 'tablet',
    'e' : 'ipad'
}

# %%
d
# Out:
# {'a': 'laptop', 'b': 'smartphone', 'c': 'landline', 'd': 'tablet', 'e': 'ipad'}

# %%
import json
with open('python.json', 'w') as file:
    json.dump(d, file)

# %%
with open('python.json', 'r') as file:
    # t1 = file.read()
    text = json.load(file)

# %%
with open('python.json', 'r') as file:
    t1 = file.read()

# %%
t1
# Out:
# '{"a": "laptop", "b": "smartphone", "c": "landline", "d": "tablet", "e": "ipad"}'

# %%
text
# Out:
# {'a': 'laptop', 'b': 'smartphone', 'c': 'landline', 'd': 'tablet', 'e': 'ipad'}

# %%
with open('python.json', 'w') as file:
    json.dump(d, file)
