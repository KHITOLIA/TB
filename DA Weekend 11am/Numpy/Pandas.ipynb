# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
singers = ['travis Scott', 'pawan singh', 'manish yadav', 'vansh tomar', 'arijit singh']

# %%
pd.Series(singers)
# Out:
# 0    travis Scott
# 1     pawan singh
# 2    manish yadav
# 3     vansh tomar
# 4    arijit singh
# dtype: object

# %%
runs = [10, 20, 15, 5, 7, 0, 30]

# %%
pd.Series(runs, name = 'No_of_runs')
# Out:
# 0    10
# 1    20
# 2    15
# 3     5
# 4     7
# 5     0
# 6    30
# Name: No_of_runs, dtype: int64

# %%
singers = ['travis Scott', 'pawan singh', 'manish yadav', 'vansh tomar', 'arijit singh']
pop = [100, 90, 150, 20, 1000]

# %%
pd.Series(pop, index = singers, name = 'popularity of all singers')
# Out:
# travis Scott     100
# pawan singh       90
# manish yadav     150
# vansh tomar       20
# arijit singh    1000
# Name: popularity of all singers, dtype: int64

# %%
marks = {
    'python' : 60,
    'cloud' : 40,
    'Ml' : 50,
    'Dl' : 90,
    'dsa' : 70
}
marks['Dl']
# Out:
# 90

# %%
marks_series = pd.Series(marks, name = 'marks of vansh')

# %%
marks_series.size
# Out:
# 5

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series[1]
# Out:
# 40

# %%
for i in marks_series.index:
    print(i)
# Out:
# python
# cloud
# Ml
# Dl
# dsa

# %%
subs = pd.read_csv('subs.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 subs = pd.read_csv('subs.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
subs.head()

# %%
subs

# %%
subs.head(7)

# %%
subs.tail(10)

# %%
kohli_df = pd.read_csv('kohli_ipl.csv', index_col='match_no')

# %%
kohli_df.head()

# %%
kohli_df.ndim

# %%
kohli_df.shape

# %%
# kohli_df.values

# %%
movies = pd.read_csv('bollywood.csv')

# %%
movies.head()

# %%
movies.reset_index()

# %%
movies.sample(5)

# %%
movies.head()

# %%
# finding how many movies done by vicky kaushal

# %%
movies.value_counts()

# %%
movies['lead'].value_counts()

# %%
movies['movie'].value_counts()

# %%
kohli_df = kohli_df.reset_index()

# %%
kohli_df

# %%
kohli_df['runs'].sort_index(ascending=False)

# %%
kohli_df.size

# %%
kohli_df.shape

# %%
215*2

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()

# %%
movies.info()

# %%
print("all columns : ")
for i in movies.columns:
    print(i)

# %%
movies = pd.read_csv('bollywood.csv')

# %%
movies.info()

# %%
movies.describe()

# %%
movies['lead'].value_counts()[movies['lead'].value_counts() > 30]

# %%
# astype
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# movies.astype?

# %%
movies = pd.read_csv('movies.csv')

# %%
numerical_col = []
categorical_col = []
for col in movies.columns:
    if movies[col].dtypes == object:
        categorical_col.append(col)
    else:
        numerical_col.append(col)

# %%
numerical_col

# %%
categorical_col

# %%
movies['title_x'] = movies['title_x'].astype(str)

# %%
movies.head()

# %%
movies.duplicated().sum()

# %%
movies.drop_duplicates(inplace = True)

# %%
(movies.isnull().sum()/movies.shape[0])*100

# %%
movies.shape[0]

# %%
(103/1629)*100

# %%
# movies.dropna(inplace = True)

# %%
ipl_match = pd.read_csv('ipl-matches.csv')

# %%
ipl_match.head()

# %%
ipl_match.isnull().sum()

# %%
ipl_match.shape

# %%
ipl_match.info()

# %%
(ipl_match['Margin'].isnull().sum()/ipl_match.shape[0])*100

# %%
margin_mean = ipl_match['Margin'].mean()

# %%
margin_median = ipl_match['Margin'].median()

# %%
# ipl_match['Margin'] = ipl_match['Margin'].fillna(margin_mean)
ipl_match['Margin'].fillna(margin_median, inplace=True)

# %%
(ipl_match['Margin'].isnull().sum()/ipl_match.shape[0])*100

# %%
ipl_match.isin(['Delhi', 'Rajasthan Royals'])

# %%
ipl_match['City'].isnull().sum()

# %%
bolly = pd.read_csv('bollywood.csv')

# %%
bolly.head()

# %%
bolly.info()

# %%
bolly['lead'] = bolly['lead'].apply(lambda x : x.lower())

# %%
bolly.head()

# %%
ipl_match.drop_duplicates(inplace=True)

# %%
ipl_match.dropna(inplace=True)

# %%
ipl_match.isnull().sum()

# %%
ipl_match['City']

# %%
ipl_match.shape

# %%
for i in range(ipl_match.shape[0]):
    ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()

# %%
ipl_match.head()

# %%
ipl_match.iloc[:5, [1, 2, 3]]

# %%
ipl_match[['City', 'Date', 'Season']]

# %%
ipl_match.sort_index(ascending=False, inplace=True)

# %%
ipl_match[['City', 'Date', 'Season']]

# %%
ipl_match.values[0].shape

# %%
ipl_match.head()

# %%
# filtering : 
# find all the teams that played in ahemdabad , delhi 
# how many teams won by wickets 
# find the number of teams who have won the toss as well as match

# %%
ipl_match[ipl_match['City'] == 'delhi']

# %%
ipl_match[ipl_match['City'] == 'ahemdabad']

# %%
ipl_match[ipl_match['WonBy'] == 'Wickets']['WinningTeam']

# %%
ipl_match[ipl_match['TossWinner'] == ipl_match['WinningTeam']].shape[0]

# %%
ipl_match

# %%
bolly.head()

# %%
# # Questions : 
# 1. find the top 3 actors most of the movies they have done
# 2. find the the movies done by top 3 actors
# 3. find the number of teams who have win the tos for batting as well as won the match 
# 4. find the man of the match whose having the max margin of score 
# 5. find the first two opener of all the teams
# 6. find all the teams that played in ahemdabad , delhi 
# 7. how many teams won by wickets 
# 8. find the number of teams who have won the toss as well as match

# %%
ipl_match['Team1Players'].iloc[0]

# %%
movies.head()

# %%
movies['title_x']

# %%
movies.iloc[0]

# %%
movies[['title_x', 'imdb_id', 'year_of_release']]

# %%
movies['title_x'] = movies['title_x'].astype(str)

# %%
categorical_features = []
numerical_features = []
for col in movies.columns:
    if movies[col].dtypes == object:
        categorical_features.append(col)
    else:
        numerical_features.append(col)

# %%
categorical_features

# %%
numerical_features

# %%
(movies.isnull().sum()/movies.shape[0])*100

# %%
movies.duplicated().sum()

# %%
movies.drop_duplicates(inplace = True)

# %%
movies.shape

# %%
movies.head()

# %%
movies['release_date'].unique()

# %%
movies[movies['release_date'] == 'TV Series (2011–2012)']

# %%
movies['release_date'].str.split("(")[3][0]

# %%
movies['release_date'][0]

# %%
for i in range(movies.shape[0]):
    movies['release_date'][i] = movies['release_date'].str.split("(")[i][0]

# %%
removed_nan_data = movies.dropna()

# %%
# movies

# %%
removed_nan_data

# %%
removed_nan_data.isnull().sum()

# %%
removed_nan_data['release_date']

# %%
removed_nan_data['release_date'].iloc[3].split("(")[0]

# %%
for i in range(removed_nan_data.shape[0]):
    removed_nan_data['release_date'].iloc[i] = removed_nan_data['release_date'].iloc[i].split("(")[0]

# %%
removed_nan_data.head()

# %%
removed_nan_data = movies.dropna()

# %%
removed_nan_data

# %%
for i in range(removed_nan_data.shape[0]):
    removed_nan_data['release_date'].iloc[i] = removed_nan_data['release_date'].iloc[i].split("(")[0]

# %%
for i in range(removed_nan_data.shape[0]):
    removed_nan_data['country'][i] = removed_nan_data['release_date'].iloc[i].split("(")[1][:-1]

# %%
l = removed_nan_data['country'].unique()

# %%
for i in l:
    print(i.split("("))
    break

# %%
# # Questions : 
# 1. find the top 3 actors most of the movies they have done
# 2. find the the movies done by top 3 actors
# 3. find the number of teams who have win the tos for batting as well as won the match 
# 4. find the man of the match whose having the max margin of score 
# 5. find the first two opener of all the teams
# 6. find all the teams that played in ahemdabad , delhi 
# 7. how many teams won by wickets 
# 8. find the number of teams who have won the toss as well as match

# %%
bolly.head()

# %%
l = list(bolly['lead'].value_counts() >= 20)

# %%
bolly['movie'].unique()

# %%
bolly['movie'].nunique()

# %%
bolly['lead'].value_counts()[bolly['lead'].value_counts() >= 20]

# %%
bolly[bolly['lead'] == 'ajay devgn']

# %%
ipl_match.shape

# %%
# ipl_match[['City', 'Team1', 'Team2']]

# %%
ipl_match = pd.read_csv('ipl-matches.csv')

# %%
ipl_match.isnull().sum()

# %%
ipl_match.head()

# %%
ipl_match[ipl_match['City'] == 'Kolkata']

# %%
ipl_match.head()

# %%
new_data = ipl_match[['TossWinner', 'TossDecision', 'WinningTeam']]

# %%
l = list(new_data[new_data['TossDecision'] == 'bat']['TossWinner'] == new_data[new_data['TossDecision'] == 'bat']['WinningTeam'])

# %%
count = 0
for i in l:
    if i == True:
        count+=1
print(count)

# %%
# 4. find the man of the match whose having the max margin of score

# %%
ipl_match[['Margin', 'Player_of_Match']]['Margin'].sort_values(ascending=False)

# %%
ipl_match[ipl_match['Margin'] == 146.0]

# %%
# 5. find the first two opener of all the teams
# 6. find all the teams that played in ahemdabad , delhi 
# 7. how many teams won by wickets

# %%
ipl_match = pd.read_csv("ipl-matches.csv")

# %%
ipl_match.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
len(ipl_match['Team1Players'].unique())
# Out:
# 932

# %%
ipl_match.shape
# Out:
# (950, 20)

# %%
len(ipl_match['Team1'].unique())
# Out:
# 18

# %%
# ipl_match['Team1Openers']

# %%
ipl_match['Team1Players'].iloc[0]
# Out:
# "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Ashwin', 'R Parag', 'TA Boult', 'OC McCoy', 'M Prasidh Krishna', 'YS Chahal']"

# %%
ipl_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl_match['Team1Players'].apply(lambda x : x.split())
# Out:
# 0      [['YBK, Jaiswal',, 'JC, Buttler',, 'SV, Samson...
# 1      [['V, Kohli',, 'F, du, Plessis',, 'RM, Patidar...
# 2      [['V, Kohli',, 'F, du, Plessis',, 'RM, Patidar...
# 3      [['YBK, Jaiswal',, 'JC, Buttler',, 'SV, Samson...
# 4      [['PK, Garg',, 'Abhishek, Sharma',, 'RA, Tripa...
#                              ...
# 945    [['WP, Saha',, 'BB, McCullum',, 'RT, Ponting',...
# 946    [['L, Ronchi',, 'ST, Jayasuriya',, 'DJ, Thorne...
# 947    [['G, Gambhir',, 'V, Sehwag',, 'S, Dhawan',, '...
# 948    [['K, Goel',, 'JR, Hopes',, 'KC, Sangakkara',,...
# 949    [['R, Dravid',, 'W, Jaffer',, 'V, Kohli',, 'JH...
# Name: Team1Players, Length: 950, dtype: object

# %%
ipl_match['Team1Players'].iloc[0].replace('[', "").split(", ")
# Out:
# ["'YBK Jaiswal'",
#  "'JC Buttler'",
#  "'SV Samson'",
#  "'D Padikkal'",
#  "'SO Hetmyer'",
#  "'R Ashwin'",
#  "'R Parag'",
#  "'TA Boult'",
#  "'OC McCoy'",
#  "'M Prasidh Krishna'",
#  "'YS Chahal']"]

# %%
ipl_match.drop(columns= ['Team1_Opener', 'Team2_Opener'], inplace = True)

# %%
ipl_match['Team1Players'].iloc[0].replace('[', "").split(", ")[0]
# Out:
# "'YBK Jaiswal'"

# %%
T1opener = []
T2opener = []
for i in range(ipl_match.shape[0]):
    T1opener.append(ipl_match['Team1Players'].iloc[i].replace('[', "").split(", ")[0] + " and " + ipl_match['Team1Players'].iloc[i].replace('[', "").split(", ")[1])
    T2opener.append(ipl_match['Team2Players'].iloc[i].replace('[', "").split(", ")[0] + " and " + ipl_match['Team2Players'].iloc[i].replace('[', "").split(", ")[1])

# %%
ipl_match['Team1_Opener'] = T1opener

# %%
ipl_match['Team2_Opener'] = T2opener

# %%
ipl_match.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
ipl_match['Team1Players'].iloc[i].replace('[', "").split(", ")[0] + "/" + ipl_match['Team1Players'].iloc[i].replace('[', "").split(", ")[1]
# Out:
# "'R Dravid'/'W Jaffer'"

# %%
insurance = pd.read_csv("insurance.csv")

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Data Analysis
insurance.groupby?
# Out:
# Signature:
# insurance.groupby(
#     by=None,
#     axis: 'Axis | lib.NoDefault' = <no_default>,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
# ...

# %%
gender_analysis = insurance.groupby('sex')

# %%
gender_analysis.count()
# Out:
#         age  bmi  children  smoker  region  charges
# sex
# female  662  662       662     662     662      662
# male    676  676       676     676     676      676

# %%
insurance[insurance['sex'] =='female']['bmi'].shape
# Out:
# (662,)

# %%
gender_analysis.sum()
# Out:
#           age        bmi  children  \
# sex
# female  26151  20110.070       711
# male    26308  20917.555       754
#
#                                                    smoker  \
# sex
# female  yesnonononoyesnonononoyesnonononononononononon...
# male    nononononononoyesnononoyesnononoyesyesnoyesnon...
#
#                                                    region       charges
# sex
# female  southwestsoutheastsoutheastnorthwestnorthwests...  8.321061e+06
# male    southeastsoutheastnorthwestnorthwestnortheastn...  9.434764e+06

# %%
gender_analysis['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
region_analysis = insurance.groupby('region')

# %%
gender_analysis.get_group('female')
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
region_analysis.get_group('northeast')['age'].mean()
# Out:
# 39.26851851851852

# %%
region_analysis['charges'].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64
