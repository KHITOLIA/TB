# %%
import numpy as np
import pandas as pd

# %%
singers = ['travis Scott', 'pawan singh', 'manish yadav', 'vansh tomar', 'arijit singh']

# %%
pd.Series(singers)
# Out:
# 0    travis Scott
# 1     pawan singh
# 2    manish yadav
# 3     vansh tomar
# 4    arijit singh
# dtype: object

# %%
runs = [10, 20, 15, 5, 7, 0, 30]

# %%
pd.Series(runs, name = 'No_of_runs')
# Out:
# 0    10
# 1    20
# 2    15
# 3     5
# 4     7
# 5     0
# 6    30
# Name: No_of_runs, dtype: int64

# %%
singers = ['travis Scott', 'pawan singh', 'manish yadav', 'vansh tomar', 'arijit singh']
pop = [100, 90, 150, 20, 1000]

# %%
pd.Series(pop, index = singers, name = 'popularity of all singers')
# Out:
# travis Scott     100
# pawan singh       90
# manish yadav     150
# vansh tomar       20
# arijit singh    1000
# Name: popularity of all singers, dtype: int64

# %%
marks = {
    'python' : 60,
    'cloud' : 40,
    'Ml' : 50,
    'Dl' : 90,
    'dsa' : 70
}
marks['Dl']
# Out:
# 90

# %%
marks_series = pd.Series(marks, name = 'marks of vansh')

# %%
marks_series.size
# Out:
# 5

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series[1]
# Out:
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\1614499712.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   marks_series[1]
# 40

# %%
for i in marks_series.index:
    print(i)
# Out:
# python
# cloud
# Ml
# Dl
# dsa

# %%
subs = pd.read_csv('subs.csv')

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.head(7)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44
# 5                  46
# 6                  33

# %%
subs.tail(10)
# Out:
#      Subscribers gained
# 355                 149
# 356                 156
# 357                 177
# 358                 210
# 359                 209
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
kohli_df = pd.read_csv('kohli_ipl.csv', index_col='match_no')

# %%
kohli_df.head()
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1

# %%
kohli_df.ndim
# Out:
# 2

# %%
kohli_df.shape
# Out:
# (215, 1)

# %%
# kohli_df.values

# %%
movies = pd.read_csv('bollywood.csv')

# %%
movies.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
movies.reset_index()
# Out:
#       index                                 movie              lead
# 0         0              Uri: The Surgical Strike     Vicky Kaushal
# 1         1                         Battalion 609       Vicky Ahuja
# 2         2  The Accidental Prime Minister (film)       Anupam Kher
# 3         3                       Why Cheat India     Emraan Hashmi
# 4         4                       Evening Shadows  Mona Ambegaonkar
# ...     ...                                   ...               ...
# 1495   1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496   1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497   1497                       Saathiya (film)      Vivek Oberoi
# 1498   1498                        Company (film)        Ajay Devgn
# 1499   1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 3 columns]

# %%
movies.sample(5)
# Out:
#                        movie             lead
# 306      Dil Toh Deewana Hai      Zeenat Aman
# 802  Saheb Biwi Aur Gangster  Jimmy Sheirgill
# 312                  M Cream        Tom Alter
# 28                    Kalank     Varun Dhawan
# 324             Raaz: Reboot    Emraan Hashmi

# %%
movies.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
# finding how many movies done by vicky kaushal

# %%
movies.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar        2
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# 1920 (film)               Rajniesh Duggall    1
# Newton (film)             Rajkummar Rao       1
#                                              ..
# Ghayal: Once Again        Sunny Deol          1
# Ghanchakkar (film)        Vidya Balan         1
# Ghajini (2008 film)       Aamir Khan          1
# Genius (2018 Hindi film)  Utkarsh Sharma      1
# Zor Lagaa Ke...Haiya!     Meghan Jadhav       1
# Name: count, Length: 1497, dtype: int64

# %%
movies['lead'].value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
movies['movie'].value_counts()
# Out:
# movie
# Tanu Weds Manu: Returns        2
# Gabbar Is Back                 2
# Andaaz                         2
# Uri: The Surgical Strike       1
# Jannat (film)                  1
#                               ..
# Hawaa Hawaai                   1
# Children of War (2014 film)    1
# The Xposé                      1
# Mastram                        1
# Awara Paagal Deewana           1
# Name: count, Length: 1497, dtype: int64

# %%
kohli_df = kohli_df.reset_index()

# %%
kohli_df
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
kohli_df['runs'].sort_index(ascending=False)
# Out:
# 214     7
# 213    25
# 212    73
# 211    20
# 210     0
#        ..
# 4       1
# 3      12
# 2      13
# 1      23
# 0       1
# Name: runs, Length: 215, dtype: int64

# %%
kohli_df.size
# Out:
# 430

# %%
kohli_df.shape
# Out:
# (215, 2)

# %%
215*2
# Out:
# 430

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                Why Cheat India                Why Cheat India         0
# 4                Evening Shadows                Evening Shadows         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
# 2             2019     112   Biography|Drama          6.1        5549
# 3             2019     121       Crime|Drama          6.0        1891
# 4             2018     102             Drama          7.3         280
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
# 2  Based on the memoir by Indian policy analyst S...
# 3  The movie focuses on existing malpractices in ...
# 4  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
# 2  Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3  The movie focuses on existing malpractices in ...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
#                                               actors        wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...                  4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...                     NaN
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...                     NaN
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...                     NaN
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...  17 wins & 1 nomination
#
#               release_date
# 0    11 January 2019 (USA)
# 1  11 January 2019 (India)
# 2    11 January 2019 (USA)
# 3    18 January 2019 (USA)
# 4  11 January 2019 (India)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
#  16  wins_nominations  707 non-null    object
#  17  release_date      1522 non-null   object
# dtypes: float64(1), int64(3), object(14)
# memory usage: 229.2+ KB

# %%
print("all columns : ")
for i in movies.columns:
    print(i)
# Out:
# all columns :
# title_x
# imdb_id
# poster_path
# wiki_link
# title_y
# original_title
# is_adult
# year_of_release
# runtime
# genres
# imdb_rating
# imdb_votes
# story
# summary
# tagline
# actors
# wins_nominations
# release_date

# %%
movies = pd.read_csv('bollywood.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movie   1500 non-null   object
#  1   lead    1500 non-null   object
# dtypes: object(2)
# memory usage: 23.6+ KB

# %%
movies.describe()
# Out:
#                           movie          lead
# count                      1500          1500
# unique                     1497           566
# top     Tanu Weds Manu: Returns  Akshay Kumar
# freq                          2            48

# %%
movies['lead'].value_counts()[movies['lead'].value_counts() > 30]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Name: count, dtype: int64

# %%
# astype
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# movies.astype?

# %%
movies = pd.read_csv('movies.csv')

# %%
numerical_col = []
categorical_col = []
for col in movies.columns:
    if movies[col].dtypes == object:
        categorical_col.append(col)
    else:
        numerical_col.append(col)

# %%
numerical_col
# Out:
# ['is_adult', 'year_of_release', 'imdb_rating', 'imdb_votes']

# %%
categorical_col
# Out:
# ['title_x',
#  'imdb_id',
#  'poster_path',
#  'wiki_link',
#  'title_y',
#  'original_title',
#  'runtime',
#  'genres',
#  'story',
#  'summary',
#  'tagline',
#  'actors',
#  'wins_nominations',
#  'release_date']

# %%
movies['title_x'] = movies['title_x'].astype(str)

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                Why Cheat India                Why Cheat India         0
# 4                Evening Shadows                Evening Shadows         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
# 2             2019     112   Biography|Drama          6.1        5549
# 3             2019     121       Crime|Drama          6.0        1891
# 4             2018     102             Drama          7.3         280
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
# 2  Based on the memoir by Indian policy analyst S...
# 3  The movie focuses on existing malpractices in ...
# 4  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
# 2  Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3  The movie focuses on existing malpractices in ...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
#                                               actors        wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...                  4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...                     NaN
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...                     NaN
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...                     NaN
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...  17 wins & 1 nomination
#
#               release_date
# 0    11 January 2019 (USA)
# 1  11 January 2019 (India)
# 2    11 January 2019 (USA)
# 3    18 January 2019 (USA)
# 4  11 January 2019 (India)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.drop_duplicates(inplace = True)

# %%
(movies.isnull().sum()/movies.shape[0])*100
# Out:
# title_x              0.000000
# imdb_id              0.000000
# poster_path          6.322897
# wiki_link            0.000000
# title_y              0.000000
# original_title       0.000000
# is_adult             0.000000
# year_of_release      0.000000
# runtime              0.000000
# genres               0.000000
# imdb_rating          0.000000
# imdb_votes           0.000000
# story                1.227747
# summary              0.000000
# tagline             65.807244
# actors               0.306937
# wins_nominations    56.599141
# release_date         6.568447
# dtype: float64

# %%
movies.shape[0]
# Out:
# 1629

# %%
(103/1629)*100
# Out:
# 6.322897483118478

# %%
# movies.dropna(inplace = True)

# %%
ipl_match = pd.read_csv('ipl-matches.csv')

# %%
ipl_match.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
ipl_match.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl_match.shape
# Out:
# (950, 20)

# %%
ipl_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
(ipl_match['Margin'].isnull().sum()/ipl_match.shape[0])*100
# Out:
# 1.8947368421052633

# %%
margin_mean = ipl_match['Margin'].mean()

# %%
margin_median = ipl_match['Margin'].median()

# %%
# ipl_match['Margin'] = ipl_match['Margin'].fillna(margin_mean)
ipl_match['Margin'].fillna(margin_median, inplace=True)
# Out:
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\1134282163.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl_match['Margin'].fillna(margin_median, inplace=True)

# %%
(ipl_match['Margin'].isnull().sum()/ipl_match.shape[0])*100
# Out:
# 0.0

# %%
ipl_match.isin(['Delhi', 'Rajasthan Royals'])
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False   True  False  False
# 1    False  False  False   False        False  False   True  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False   True  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False   True  False   False        False  False   True  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0          True         False      False        False  False   False   False
# 1          True         False      False         True  False   False   False
# 2         False         False      False        False  False   False   False
# 3         False         False      False        False  False   False   False
# 4         False         False      False        False  False   False   False
# ..          ...           ...        ...          ...    ...     ...     ...
# 945       False         False      False        False  False   False   False
# 946       False         False      False        False  False   False   False
# 947        True         False      False        False  False   False   False
# 948       False         False      False        False  False   False   False
# 949       False         False      False        False  False   False   False
#
#      Player_of_Match  Team1Players  Team2Players  Umpire1  Umpire2
# 0              False         False         False    False    False
# 1              False         False         False    False    False
# 2              False         False         False    False    False
# 3              False         False         False    False    False
# 4              False         False         False    False    False
# ..               ...           ...           ...      ...      ...
# 945            False         False         False    False    False
# 946            False         False         False    False    False
# 947            False         False         False    False    False
# 948            False         False         False    False    False
# 949            False         False         False    False    False
#
# [950 rows x 20 columns]

# %%
ipl_match['City'].isnull().sum()
# Out:
# 51

# %%
bolly = pd.read_csv('bollywood.csv')

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
bolly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movie   1500 non-null   object
#  1   lead    1500 non-null   object
# dtypes: object(2)
# memory usage: 23.6+ KB

# %%
bolly['lead'] = bolly['lead'].apply(lambda x : x.lower())

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     vicky kaushal
# 1                         Battalion 609       vicky ahuja
# 2  The Accidental Prime Minister (film)       anupam kher
# 3                       Why Cheat India     emraan hashmi
# 4                       Evening Shadows  mona ambegaonkar

# %%
ipl_match.drop_duplicates(inplace=True)

# %%
ipl_match.dropna(inplace=True)

# %%
ipl_match.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
ipl_match['City']
# Out:
# 282            Delhi
# 296          Kolkata
# 308           Jaipur
# 316        Bangalore
# 383        Bangalore
# 384    Visakhapatnam
# 389          Kolkata
# 411        Hyderabad
# 441        Hyderabad
# 472    Visakhapatnam
# 520            Delhi
# 717        Bangalore
# 728          Kolkata
# 757            Kochi
# 860        Centurion
# 886           Durban
# 889        Cape Town
# 908          Kolkata
# 910            Delhi
# Name: City, dtype: object

# %%
ipl_match.shape
# Out:
# (19, 20)

# %%
for i in range(ipl_match.shape[0]):
    ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# Out:
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()
# C:\Users\tbaka\AppData\Local\Temp\ipykernel_3188\695304738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_match['City'].iloc[i] = ipl_match['City'].iloc[i].lower()

# %%
ipl_match.head()
# Out:
#           ID       City        Date Season MatchNumber  \
# 282  1136592      delhi  2018-05-02   2018          32
# 296  1136578    kolkata  2018-04-21   2018          18
# 308  1136566     jaipur  2018-04-11   2018           6
# 316  1082648  bangalore  2017-05-17   2017  Eliminator
# 383   980999  bangalore  2016-05-18   2016          50
#
#                            Team1                  Team2  \
# 282             Delhi Daredevils       Rajasthan Royals
# 296        Kolkata Knight Riders        Kings XI Punjab
# 308             Rajasthan Royals       Delhi Daredevils
# 316          Sunrisers Hyderabad  Kolkata Knight Riders
# 383  Royal Challengers Bangalore        Kings XI Punjab
#
#                       Venue             TossWinner TossDecision SuperOver  \
# 282    Arun Jaitley Stadium       Rajasthan Royals        field         N
# 296            Eden Gardens        Kings XI Punjab        field         N
# 308  Sawai Mansingh Stadium       Delhi Daredevils        field         N
# 316   M Chinnaswamy Stadium  Kolkata Knight Riders        field         N
# 383   M Chinnaswamy Stadium        Kings XI Punjab        field         N
#
#                      WinningTeam    WonBy  Margin method  Player_of_Match  \
# 282             Delhi Daredevils     Runs     4.0    D/L          RR Pant
# 296              Kings XI Punjab  Wickets     9.0    D/L         KL Rahul
# 308             Rajasthan Royals     Runs    10.0    D/L        SV Samson
# 316        Kolkata Knight Riders  Wickets     7.0    D/L  NM Coulter-Nile
# 383  Royal Challengers Bangalore     Runs    82.0    D/L          V Kohli
#
#                                           Team1Players  \
# 282  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
# 296  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...
# 308  ['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Sa...
# 316  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 383  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
#
#                                           Team2Players                Umpire1  \
# 282  ['DJM Short', 'JC Buttler', 'SV Samson', 'BA S...              CK Nandan
# 296  ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nai...             A Deshmukh
# 308  ['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morri...  KN Ananthapadmanabhan
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...           AK Chaudhary
# 383  ['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller',...  KN Ananthapadmanabhan
#
#            Umpire2
# 282      VK Sharma
# 296  C Shamshuddin
# 308    Nitin Menon
# 316    Nitin Menon
# 383      M Erasmus

# %%
ipl_match.iloc[:5, [1, 2, 3]]
# Out:
#           City        Date Season
# 282      delhi  2018-05-02   2018
# 296    kolkata  2018-04-21   2018
# 308     jaipur  2018-04-11   2018
# 316  bangalore  2017-05-17   2017
# 383  bangalore  2016-05-18   2016

# %%
ipl_match[['City', 'Date', 'Season']]
# Out:
#               City        Date   Season
# 282          delhi  2018-05-02     2018
# 296        kolkata  2018-04-21     2018
# 308         jaipur  2018-04-11     2018
# 316      bangalore  2017-05-17     2017
# 383      bangalore  2016-05-18     2016
# 384  visakhapatnam  2016-05-17     2016
# 389        kolkata  2016-05-14     2016
# 411      hyderabad  2016-04-26     2016
# 441      hyderabad  2015-05-15     2015
# 472  visakhapatnam  2015-04-22     2015
# 520          delhi  2014-05-10     2014
# 717      bangalore  2011-05-14     2011
# 728        kolkata  2011-05-07     2011
# 757          kochi  2011-04-18     2011
# 860      centurion  2009-05-07     2009
# 886         durban  2009-04-21     2009
# 889      cape town  2009-04-19     2009
# 908        kolkata  2008-05-18  2007/08
# 910          delhi  2008-05-17  2007/08

# %%
ipl_match.sort_index(ascending=False, inplace=True)

# %%
ipl_match[['City', 'Date', 'Season']]
# Out:
#               City        Date   Season
# 910          delhi  2008-05-17  2007/08
# 908        kolkata  2008-05-18  2007/08
# 889      cape town  2009-04-19     2009
# 886         durban  2009-04-21     2009
# 860      centurion  2009-05-07     2009
# 757          kochi  2011-04-18     2011
# 728        kolkata  2011-05-07     2011
# 717      bangalore  2011-05-14     2011
# 520          delhi  2014-05-10     2014
# 472  visakhapatnam  2015-04-22     2015
# 441      hyderabad  2015-05-15     2015
# 411      hyderabad  2016-04-26     2016
# 389        kolkata  2016-05-14     2016
# 384  visakhapatnam  2016-05-17     2016
# 383      bangalore  2016-05-18     2016
# 316      bangalore  2017-05-17     2017
# 308         jaipur  2018-04-11     2018
# 296        kolkata  2018-04-21     2018
# 282          delhi  2018-05-02     2018

# %%
ipl_match.values[0].shape
# Out:
# (20,)

# %%
ipl_match.head()
# Out:
#          ID       City        Date   Season MatchNumber  \
# 910  336022      delhi  2008-05-17  2007/08          40
# 908  336025    kolkata  2008-05-18  2007/08          41
# 889  392183  cape town  2009-04-19     2009           3
# 886  392186     durban  2009-04-21     2009           6
# 860  392214  centurion  2009-05-07     2009          34
#
#                      Team1                  Team2             Venue  \
# 910       Delhi Daredevils        Kings XI Punjab  Feroz Shah Kotla
# 908  Kolkata Knight Riders    Chennai Super Kings      Eden Gardens
# 889       Delhi Daredevils        Kings XI Punjab          Newlands
# 886        Kings XI Punjab  Kolkata Knight Riders         Kingsmead
# 860    Chennai Super Kings        Kings XI Punjab   SuperSport Park
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# 910       Delhi Daredevils          bat         N        Kings XI Punjab
# 908  Kolkata Knight Riders          bat         N    Chennai Super Kings
# 889       Delhi Daredevils        field         N       Delhi Daredevils
# 886  Kolkata Knight Riders        field         N  Kolkata Knight Riders
# 860    Chennai Super Kings          bat         N    Chennai Super Kings
#
#        WonBy  Margin method   Player_of_Match  \
# 910     Runs     6.0    D/L  DPMD Jayawardene
# 908     Runs     3.0    D/L           M Ntini
# 889  Wickets    10.0    D/L        DL Vettori
# 886     Runs    11.0    D/L          CH Gayle
# 860     Runs    12.0    D/L         ML Hayden
#
#                                           Team1Players  \
# 910  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dils...
# 908  ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly...
# 889  ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de...
# 886  ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sanga...
# 860  ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS D...
#
#                                           Team2Players         Umpire1  \
# 910  ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA P...  AV Jayaprakash
# 908  ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Rai...       Asad Rauf
# 889  ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sa...       MR Benson
# 886  ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ga...       DJ Harper
# 860  ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Sin...       DJ Harper
#
#             Umpire2
# 910     RE Koertzen
# 908     K Hariharan
# 889       SD Ranade
# 886       SD Ranade
# 860  TH Wijewardene

# %%
# filtering : 
# find all the teams that played in ahemdabad , delhi 
# how many teams won by wickets 
# find the number of teams who have won the toss as well as match

# %%
ipl_match[ipl_match['City'] == 'delhi']
# Out:
#           ID   City        Date   Season MatchNumber             Team1  \
# 910   336022  delhi  2008-05-17  2007/08          40  Delhi Daredevils
# 520   733993  delhi  2014-05-10     2014          32  Delhi Daredevils
# 282  1136592  delhi  2018-05-02     2018          32  Delhi Daredevils
#
#                    Team2                 Venue           TossWinner  \
# 910      Kings XI Punjab      Feroz Shah Kotla     Delhi Daredevils
# 520  Sunrisers Hyderabad      Feroz Shah Kotla  Sunrisers Hyderabad
# 282     Rajasthan Royals  Arun Jaitley Stadium     Rajasthan Royals
#
#     TossDecision SuperOver          WinningTeam    WonBy  Margin method  \
# 910          bat         N      Kings XI Punjab     Runs     6.0    D/L
# 520        field         N  Sunrisers Hyderabad  Wickets     8.0    D/L
# 282        field         N     Delhi Daredevils     Runs     4.0    D/L
#
#       Player_of_Match                                       Team1Players  \
# 910  DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dils...
# 520          DW Steyn  ['Q de Kock', 'KP Pietersen', 'MA Agarwal', 'K...
# 282           RR Pant  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
#
#                                           Team2Players         Umpire1  \
# 910  ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA P...  AV Jayaprakash
# 520  ['AJ Finch', 'S Dhawan', 'DA Warner', 'NV Ojha...    RM Deshpande
# 282  ['DJM Short', 'JC Buttler', 'SV Samson', 'BA S...       CK Nandan
#
#           Umpire2
# 910   RE Koertzen
# 520  BNJ Oxenford
# 282     VK Sharma

# %%
ipl_match[ipl_match['City'] == 'ahemdabad']
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
ipl_match[ipl_match['WonBy'] == 'Wickets']['WinningTeam']
# Out:
# 889               Delhi Daredevils
# 757           Kochi Tuskers Kerala
# 717    Royal Challengers Bangalore
# 520            Sunrisers Hyderabad
# 441    Royal Challengers Bangalore
# 389          Kolkata Knight Riders
# 316          Kolkata Knight Riders
# 296                Kings XI Punjab
# Name: WinningTeam, dtype: object

# %%
ipl_match[ipl_match['TossWinner'] == ipl_match['WinningTeam']].shape[0]
# Out:
# 10

# %%
ipl_match
# Out:
#           ID           City        Date   Season MatchNumber  \
# 910   336022          delhi  2008-05-17  2007/08          40
# 908   336025        kolkata  2008-05-18  2007/08          41
# 889   392183      cape town  2009-04-19     2009           3
# 886   392186         durban  2009-04-21     2009           6
# 860   392214      centurion  2009-05-07     2009          34
# 757   501215          kochi  2011-04-18     2011          18
# 728   501245        kolkata  2011-05-07     2011          48
# 717   501255      bangalore  2011-05-14     2011          58
# 520   733993          delhi  2014-05-10     2014          32
# 472   829743  visakhapatnam  2015-04-22     2015          19
# 441   829807      hyderabad  2015-05-15     2015          52
# 411   980943      hyderabad  2016-04-26     2016          22
# 389   980989        kolkata  2016-05-14     2016          45
# 384   980997  visakhapatnam  2016-05-17     2016          49
# 383   980999      bangalore  2016-05-18     2016          50
# 316  1082648      bangalore  2017-05-17     2017  Eliminator
# 308  1136566         jaipur  2018-04-11     2018           6
# 296  1136578        kolkata  2018-04-21     2018          18
# 282  1136592          delhi  2018-05-02     2018          32
#
#                            Team1                        Team2  \
# 910             Delhi Daredevils              Kings XI Punjab
# 908        Kolkata Knight Riders          Chennai Super Kings
# 889             Delhi Daredevils              Kings XI Punjab
# 886              Kings XI Punjab        Kolkata Knight Riders
# 860          Chennai Super Kings              Kings XI Punjab
# 757         Kochi Tuskers Kerala          Chennai Super Kings
# 728        Kolkata Knight Riders          Chennai Super Kings
# 717  Royal Challengers Bangalore        Kolkata Knight Riders
# 520             Delhi Daredevils          Sunrisers Hyderabad
# 472          Sunrisers Hyderabad        Kolkata Knight Riders
# 441          Sunrisers Hyderabad  Royal Challengers Bangalore
# 411          Sunrisers Hyderabad      Rising Pune Supergiants
# 389        Kolkata Knight Riders      Rising Pune Supergiants
# 384      Rising Pune Supergiants             Delhi Daredevils
# 383  Royal Challengers Bangalore              Kings XI Punjab
# 316          Sunrisers Hyderabad        Kolkata Knight Riders
# 308             Rajasthan Royals             Delhi Daredevils
# 296        Kolkata Knight Riders              Kings XI Punjab
# 282             Delhi Daredevils             Rajasthan Royals
#
#                                                  Venue  \
# 910                                   Feroz Shah Kotla
# 908                                       Eden Gardens
# 889                                           Newlands
# 886                                          Kingsmead
# 860                                    SuperSport Park
# 757                                      Nehru Stadium
# 728                                       Eden Gardens
# 717                              M Chinnaswamy Stadium
# 520                                   Feroz Shah Kotla
# 472  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 441          Rajiv Gandhi International Stadium, Uppal
# 411          Rajiv Gandhi International Stadium, Uppal
# 389                                       Eden Gardens
# 384  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 383                              M Chinnaswamy Stadium
# 316                              M Chinnaswamy Stadium
# 308                             Sawai Mansingh Stadium
# 296                                       Eden Gardens
# 282                               Arun Jaitley Stadium
#
#                       TossWinner TossDecision SuperOver  \
# 910             Delhi Daredevils          bat         N
# 908        Kolkata Knight Riders          bat         N
# 889             Delhi Daredevils        field         N
# 886        Kolkata Knight Riders        field         N
# 860          Chennai Super Kings          bat         N
# 757         Kochi Tuskers Kerala        field         N
# 728          Chennai Super Kings          bat         N
# 717  Royal Challengers Bangalore        field         N
# 520          Sunrisers Hyderabad        field         N
# 472        Kolkata Knight Riders        field         N
# 441          Sunrisers Hyderabad          bat         N
# 411      Rising Pune Supergiants        field         N
# 389      Rising Pune Supergiants          bat         N
# 384      Rising Pune Supergiants        field         N
# 383              Kings XI Punjab        field         N
# 316        Kolkata Knight Riders        field         N
# 308             Delhi Daredevils        field         N
# 296              Kings XI Punjab        field         N
# 282             Rajasthan Royals        field         N
#
#                      WinningTeam    WonBy  Margin method   Player_of_Match  \
# 910              Kings XI Punjab     Runs     6.0    D/L  DPMD Jayawardene
# 908          Chennai Super Kings     Runs     3.0    D/L           M Ntini
# 889             Delhi Daredevils  Wickets    10.0    D/L        DL Vettori
# 886        Kolkata Knight Riders     Runs    11.0    D/L          CH Gayle
# 860          Chennai Super Kings     Runs    12.0    D/L         ML Hayden
# 757         Kochi Tuskers Kerala  Wickets     7.0    D/L       BB McCullum
# 728        Kolkata Knight Riders     Runs    10.0    D/L     Iqbal Abdulla
# 717  Royal Challengers Bangalore  Wickets     4.0    D/L          CH Gayle
# 520          Sunrisers Hyderabad  Wickets     8.0    D/L          DW Steyn
# 472          Sunrisers Hyderabad     Runs    16.0    D/L         DA Warner
# 441  Royal Challengers Bangalore  Wickets     6.0    D/L           V Kohli
# 411      Rising Pune Supergiants     Runs    34.0    D/L          AB Dinda
# 389        Kolkata Knight Riders  Wickets     8.0    D/L         YK Pathan
# 384      Rising Pune Supergiants     Runs    19.0    D/L          AB Dinda
# 383  Royal Challengers Bangalore     Runs    82.0    D/L           V Kohli
# 316        Kolkata Knight Riders  Wickets     7.0    D/L   NM Coulter-Nile
# 308             Rajasthan Royals     Runs    10.0    D/L         SV Samson
# 296              Kings XI Punjab  Wickets     9.0    D/L          KL Rahul
# 282             Delhi Daredevils     Runs     4.0    D/L           RR Pant
#
#                                           Team1Players  \
# 910  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dils...
# 908  ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly...
# 889  ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de...
# 886  ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sanga...
# 860  ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS D...
# 757  ['BB McCullum', 'DPMD Jayawardene', 'PA Patel'...
# 728  ['EJG Morgan', 'JH Kallis', 'G Gambhir', 'MK T...
# 717  ['CH Gayle', 'LA Pomersbach', 'V Kohli', 'AB d...
# 520  ['Q de Kock', 'KP Pietersen', 'MA Agarwal', 'K...
# 472  ['S Dhawan', 'DA Warner', 'RS Bopara', 'NV Ojh...
# 441  ['DA Warner', 'S Dhawan', 'MC Henriques', 'EJG...
# 411  ['DA Warner', 'S Dhawan', 'AP Tare', 'EJG Morg...
# 389  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 384  ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS T...
# 383  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
# 316  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 308  ['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Sa...
# 296  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...
# 282  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
#
#                                           Team2Players                Umpire1  \
# 910  ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA P...         AV Jayaprakash
# 908  ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Rai...              Asad Rauf
# 889  ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sa...              MR Benson
# 886  ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ga...              DJ Harper
# 860  ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Sin...              DJ Harper
# 757  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...            K Hariharan
# 728  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...              Asad Rauf
# 717  ['JH Kallis', 'EJG Morgan', 'G Gambhir', 'MK T...            RE Koertzen
# 520  ['AJ Finch', 'S Dhawan', 'DA Warner', 'NV Ojha...           RM Deshpande
# 472  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'AD R...         RK Illingworth
# 441  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Man...           AK Chaudhary
# 411  ['AM Rahane', 'F du Plessis', 'SPD Smith', 'MS...            AY Dandekar
# 389  ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS T...         A Nand Kishore
# 384  ['Q de Kock', 'SS Iyer', 'KK Nair', 'SV Samson...            Nitin Menon
# 383  ['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller',...  KN Ananthapadmanabhan
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...           AK Chaudhary
# 308  ['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morri...  KN Ananthapadmanabhan
# 296  ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nai...             A Deshmukh
# 282  ['DJM Short', 'JC Buttler', 'SV Samson', 'BA S...              CK Nandan
#
#              Umpire2
# 910      RE Koertzen
# 908      K Hariharan
# 889        SD Ranade
# 886        SD Ranade
# 860   TH Wijewardene
# 757          AL Hill
# 728       PR Reiffel
# 717        RB Tiffin
# 520     BNJ Oxenford
# 472      VA Kulkarni
# 441  HDPK Dharmasena
# 411        CK Nandan
# 389     BNJ Oxenford
# 384    C Shamshuddin
# 383        M Erasmus
# 316      Nitin Menon
# 308      Nitin Menon
# 296    C Shamshuddin
# 282        VK Sharma

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     vicky kaushal
# 1                         Battalion 609       vicky ahuja
# 2  The Accidental Prime Minister (film)       anupam kher
# 3                       Why Cheat India     emraan hashmi
# 4                       Evening Shadows  mona ambegaonkar

# %%
# # Questions : 
# 1. find the top 3 actors most of the movies they have done
# 2. find the the movies done by top 3 actors
# 3. find the number of teams who have win the tos for batting as well as won the match 
# 4. find the man of the match whose having the max margin of score 
# 5. find the first two opener of all the teams
# 6. find all the teams that played in ahemdabad , delhi 
# 7. how many teams won by wickets 
# 8. find the number of teams who have won the toss as well as match

# %%
ipl_match['Team1Players'].iloc[0]
# Out:
# "['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dilshan', 'MF Maharoof', 'Shoaib Malik', 'PJ Sangwan', 'KD Karthik', 'A Mishra', 'R Bhatia', 'GD McGrath']"
