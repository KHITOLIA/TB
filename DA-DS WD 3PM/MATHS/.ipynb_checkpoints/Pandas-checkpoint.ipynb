# %%
# Pandas

# %%
import pandas as pd
import numpy as np

# %%
# pandas Series : any columns in any table (1-D array)

# %%
country = ['India', 'USA', 'USSR', 'Nepal', 'SriLanka']
df = pd.Series(country)

# %%
df
# Out:
# 0       India
# 1         USA
# 2        USSR
# 3       Nepal
# 4    SriLanka
# dtype: object

# %%
# integers 
runs = [30, 19, 20, 15, 10]
runs_scored = pd.Series(runs)

# %%
runs_scored
# Out:
# 0    30
# 1    19
# 2    20
# 3    15
# 4    10
# dtype: int64

# %%
# Custom Index
marks = [67, 89, 100, 90, 70]

subjects = ['PE', 'CS', 'Maths', 'Physics', 'Chem']

# %%
pd.Series(marks, index=subjects, name='Marks of Agrim')
# Out:
# PE          67
# CS          89
# Maths      100
# Physics     90
# Chem        70
# Name: Marks of Agrim, dtype: int64

# %%
# Series from dict

# %%
marks = {
    'maths' : 100,
    'PE' : 67, 
    'CS' : 89,
    'Physics' : 90,
    'Chem' : 70
}

# %%
marks_series = pd.Series(marks, name = "Marks of Agrim")

# %%
marks_series
# Out:
# maths      100
# PE          67
# CS          89
# Physics     90
# Chem        70
# Name: Marks of Agrim, dtype: int64

# %%
# Series Attributes
marks_series.size
# Out:
# 5

# %%
marks_series.dtypes
# Out:
# dtype('int64')

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1, 1, 2, 2, 3, 4]).is_unique
# Out:
# False

# %%
marks_series.index
# Out:
# Index(['maths', 'PE', 'CS', 'Physics', 'Chem'], dtype='object')

# %%
type(marks_series)
# Out:
# pandas.core.series.Series

# %%
marks_series.values.shape
# Out:
# (5,)

# %%
marks_series
# Out:
# maths      100
# PE          67
# CS          89
# Physics     90
# Chem        70
# Name: Marks of Agrim, dtype: int64

# %%
# Dataset load
subs = pd.read_csv('subs.csv')

# %%
# ; -> semicolon separated values

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
manisha_ke_runs = pd.read_csv('kohli_ipl.csv', index_col = 'match_no')

# %%
manisha_ke_runs
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
bolly = pd.read_csv('bollywood.csv', index_col = 'movie')

# %%
bolly
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# Method 
bolly.head() # first 5 rows in my data
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
bolly.tail()
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
bolly
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
bolly.sample(10)
# Out:
#                                             lead
# movie
# Good Newwz                          Akshay Kumar
# Thanks Maa                          Master Shams
# Irada (2017 film)               Naseeruddin Shah
# Sikandar (2009 film)              Parzaan Dastur
# Jai Veeru                           Fardeen Khan
# Yadvi – The Dignified Princess      Prisha Aneja
# Dhadak                            Ishaan Khattar
# Dirty Politics (film)                Anupam Kher
# Staying Alive (2012 film)          Jahangir Khan
# Action Jackson (2014 film)               Prabhas

# %%
bolly
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
bolly.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.sort_index(ascending=False)
# Out:
#      Subscribers gained
# 364                 172
# 363                 144
# 362                 155
# 361                 226
# 360                 231
# ..                  ...
# 4                    44
# 3                    43
# 2                    40
# 1                    57
# 0                    48
#
# [365 rows x 1 columns]

# %%
subs['Subscribers gained'].value_counts()
# Out:
# Subscribers gained
# 105    9
# 108    6
# 123    5
# 72     5
# 88     5
#       ..
# 125    1
# 139    1
# 124    1
# 57     1
# 144    1
# Name: count, Length: 180, dtype: int64

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.sort_values(by = 'Subscribers gained',inplace= True)

# %%
subs
# Out:
#      Subscribers gained
# 42                   33
# 6                    33
# 24                   35
# 19                   37
# 14                   39
# ..                  ...
# 280                 295
# 233                 301
# 168                 306
# 331                 312
# 330                 396
#
# [365 rows x 1 columns]

# %%
bolly
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
manisha_ke_runs
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# average runs scored by manisha 
manisha_ke_runs['runs'].mean()
# Out:
# 30.855813953488372

# %%
manisha_ke_runs['runs'].max()
# Out:
# 113

# %%
manisha_ke_runs['runs'].min()
# Out:
# 0

# %%
manisha_ke_runs['runs'].sum()/manisha_ke_runs.shape[0]
# Out:
# 30.855813953488372

# %%
manisha_ke_runs.shape[0]
# Out:
# 215

# %%
bolly = pd.read_csv('bollywood.csv')

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
bolly.shape
# Out:
# (1500, 2)

# %%
bolly.iloc[0]
# Out:
# movie    Uri: The Surgical Strike
# lead                Vicky Kaushal
# Name: 0, dtype: object

# %%
bolly.iloc[:5, :]
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
bolly.iloc[[0, 4, 6], 1]
# Out:
# 0       Vicky Kaushal
# 4    Mona Ambegaonkar
# 6        Arshad Warsi
# Name: lead, dtype: object

# %%
lead_count = bolly['lead'].value_counts()

# %%
lead_count[bolly['lead'].value_counts() >= 30]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Name: count, dtype: int64

# %%
bolly[bolly['lead'] == 'Akshay Kumar'].sort_index()
# Out:
#                                      movie          lead
# 22                           Kesari (film)  Akshay Kumar
# 50                          Mission Mangal  Akshay Kumar
# 61                             Housefull 4  Akshay Kumar
# 79                              Good Newwz  Akshay Kumar
# 122                       Gold (2018 film)  Akshay Kumar
# 211                  Toilet: Ek Prem Katha  Akshay Kumar
# 256                         Airlift (film)  Akshay Kumar
# 365                 Baby (2015 Hindi film)  Akshay Kumar
# 366                        Singh Is Bliing  Akshay Kumar
# 367                         Gabbar Is Back  Akshay Kumar
# 368                         Gabbar Is Back  Akshay Kumar
# 429                   Brothers (2015 film)  Akshay Kumar
# 519   Holiday: A Soldier Is Never Off Duty  Akshay Kumar
# 523              Entertainment (2014 film)  Akshay Kumar
# 552                          The Shaukeens  Akshay Kumar
# ...

# %%
# astype
# between
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# Information about my data
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# some sort of statistics
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
(movies.isnull().sum()/movies.shape[0])*100
# Out:
# title_x              0.000000
# imdb_id              0.000000
# poster_path          6.322897
# wiki_link            0.000000
# title_y              0.000000
# original_title       0.000000
# is_adult             0.000000
# year_of_release      0.000000
# runtime              0.000000
# genres               0.000000
# imdb_rating          0.000000
# imdb_votes           0.000000
# story                1.227747
# summary              0.000000
# tagline             65.807244
# actors               0.306937
# wins_nominations    56.599141
# release_date         6.568447
# dtype: float64

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.drop_duplicates(inplace = True)

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl_matches = pd.read_csv('ipl-matches.csv')

# %%
ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl_matches.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
(ipl_matches.isnull().sum()/ipl_matches.shape[0])*100
# Out:
# ID                  0.000000
# City                5.368421
# Date                0.000000
# Season              0.000000
# MatchNumber         0.000000
# Team1               0.000000
# Team2               0.000000
# Venue               0.000000
# TossWinner          0.000000
# TossDecision        0.000000
# SuperOver           0.421053
# WinningTeam         0.421053
# WonBy               0.000000
# Margin              1.894737
# method             98.000000
# Player_of_Match     0.421053
# Team1Players        0.000000
# Team2Players        0.000000
# Umpire1             0.000000
# Umpire2             0.000000
# dtype: float64

# %%
ipl_matches.drop(columns = ['method'], inplace = True)

# %%
(ipl_matches.isnull().sum()/ipl_matches.shape[0])*100
# Out:
# ID                 0.000000
# City               5.368421
# Date               0.000000
# Season             0.000000
# MatchNumber        0.000000
# Team1              0.000000
# Team2              0.000000
# Venue              0.000000
# TossWinner         0.000000
# TossDecision       0.000000
# SuperOver          0.421053
# WinningTeam        0.421053
# WonBy              0.000000
# Margin             1.894737
# Player_of_Match    0.421053
# Team1Players       0.000000
# Team2Players       0.000000
# Umpire1            0.000000
# Umpire2            0.000000
# dtype: float64

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_matches[ipl_matches.isin(['Mumbai', 'Ahemdabad'])]
# Out:
#      ID    City Date Season MatchNumber Team1 Team2 Venue TossWinner  \
# 0   NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 1   NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 2   NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 3   NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 4   NaN  Mumbai  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# ..   ..     ...  ...    ...         ...   ...   ...   ...        ...
# 945 NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 946 NaN  Mumbai  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 947 NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 948 NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
# 949 NaN     NaN  NaN    NaN         NaN   NaN   NaN   NaN        NaN
#
#     TossDecision SuperOver WinningTeam WonBy  Margin Player_of_Match  \
# ...

# %%
ipl_matches[(ipl_matches['City'] == 'Ahmedabad') & (ipl_matches['Season'] == '2015')]
# Out:
#          ID       City        Date Season MatchNumber             Team1  \
# 470  829749  Ahmedabad  2015-04-24   2015          22  Rajasthan Royals
# 474  829741  Ahmedabad  2015-04-21   2015          18  Rajasthan Royals
# 476  829735  Ahmedabad  2015-04-19   2015          15  Rajasthan Royals
# 483  829721  Ahmedabad  2015-04-14   2015           9  Rajasthan Royals
#
#                            Team2                         Venue  \
# 470  Royal Challengers Bangalore  Sardar Patel Stadium, Motera
# 474              Kings XI Punjab  Sardar Patel Stadium, Motera
# 476          Chennai Super Kings  Sardar Patel Stadium, Motera
# 483               Mumbai Indians  Sardar Patel Stadium, Motera
#
#                       TossWinner TossDecision SuperOver  \
# 470  Royal Challengers Bangalore        field         N
# 474              Kings XI Punjab        field         Y
# 476          Chennai Super Kings          bat         N
# 483               Mumbai Indians          bat         N
#
# ...

# %%
ipl_matches[ipl_matches['Margin'].between(3, 8)]
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 0    1312200  Ahmedabad  2022-05-29     2022        Final
# 1    1312199  Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197    Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116     Mumbai  2022-05-22     2022           70
# 5    1304115     Mumbai  2022-05-21     2022           69
# ..       ...        ...         ...      ...          ...
# 941   335990  Hyderabad  2008-04-24  2007/08            9
# 942   335989    Chennai  2008-04-23  2007/08            8
# 944   335987     Jaipur  2008-04-21  2007/08            6
# 945   335986    Kolkata  2008-04-20  2007/08            4
# 946   335985     Mumbai  2008-04-20  2007/08            5
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 3               Rajasthan Royals               Gujarat Titans
# ...

# %%
ipl_matches['TossDecision'] = ipl_matches['TossDecision'].apply(lambda x : x.capitalize())

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          Bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        Field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        Field
# ...

# %%
ipl_matches['Margin'] = ipl_matches['Margin'].apply(lambda x : "High Margin" if x >= 7.0 else "Low Margin")

# %%
ipl_matches['City'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Kochi', 'Nagpur', 'Johannesburg', 'Centurion',
#        'Durban', 'Bloemfontein', 'Port Elizabeth', 'Kimberley',
#        'East London', 'Cape Town'], dtype=object)

# %%
ipl_matches['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl_matches['City'].nunique()
# Out:
# 33

# %%
subs.values
# Out:
# array([[ 33],
#        [ 33],
#        [ 35],
#        [ 37],
#        [ 39],
#        [ 40],
#        [ 40],
#        [ 40],
#        [ 40],
#        [ 42],
#        [ 42],
#        [ 43],
#        [ 44],
#        [ 44],
#        [ 44],
#        [ 45],
#        [ 46],
#        [ 46],
#        [ 48],
#        [ 49],
#        [ 49],
#        [ 49],
#        [ 49],
#        [ 50],
#        [ 50],
#        [ 50],
#        [ 51],
#        [ 54],
#        [ 56],
#        [ 56],
#        [ 56],
#        [ 56],
#        [ 57],
#        [ 61],
#        [ 62],
#        [ 64],
#        [ 65],
#        [ 65],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 67],
#        [ 68],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 71],
#        [ 71],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 73],
#        [ 74],
#        [ 74],
#        [ 75],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
# ...

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          Bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        Field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        Field
# ...

# %%
ipl_matches.to_csv('Changes_ipl_matches.csv')

# %%
a = {
    'name' : ['manisha', 'mukul', 'agrim'],
    'marks' : [89, 99, 80],
    'course' : ['DA', 'DS', 'DS'],
    'fee' : [40000, 26000,  26000]
}

# %%
pd.DataFrame(a)
# Out:
#       name  marks course    fee
# 0  manisha     89     DA  40000
# 1    mukul     99     DS  26000
# 2    agrim     80     DS  26000

# %%
import warnings
warnings.filterwarnings("ignore")
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("figolm10/insurance-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\tbaka\.cache\kagglehub\datasets\figolm10\insurance-dataset\versions\1

# %%
import os
for file in os.listdir(path):
    print(file)
# Out:
# insurance.csv

# %%
pd.read_csv(path + '\insurance.csv' )
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# find the main actor of all movies
# find all the movies having genres as Drama and it's rating > 6
# find all the teams played who against Rajasthan royal
# find all the teams played at delhi, Ahemdabad, Mumbai
# find the average margin won by Sunrisers Hyderabad, Punjab Kings, Gujrat titans, Rajasthan royal
# find all the those teams who won the toss as well as match
# find all the those teams who won the toss as well as match but decided to bat first

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies['actors'].hasnans
# Out:
# False

# %%
movies.dropna?
# Out:
# Signature:
# movies.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
# ...

# %%
movies = movies.dropna()

# %%
movies.isnull().sum()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# dtype: int64

# %%
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
movies['actors'].iloc[0] = movies['actors'].iloc[0].split("|")[0]

# %%
for i in range(movies.shape[0]):
    movies['actors'].iloc[i] = movies['actors'].iloc[i].split("|")[0]

# %%
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
df = pd.read_csv('movies.csv')

# %%
df[(df['genres'] == 'Drama') & (df['imdb_rating'] >= 6.0)]
# Out:
#                            title_x     imdb_id  \
# 4                  Evening Shadows   tt6028796
# 5                      Soni (film)   tt6078866
# 17                    Hamid (film)   tt7527082
# 20       Mere Pyare Prime Minister   tt8207768
# 25                       Gone Kesh  tt10017956
# ...                            ...         ...
# 1474  Praan Jaye Par Shaan Na Jaye   tt0330783
# 1483           Tehzeeb (2003 film)   tt0348172
# 1543                Mitr My Friend   tt0292113
# 1595                        Dattak   tt0284999
# 1601              Maya (2001 film)   tt0299027
#
#                                             poster_path  \
# 4                                                   NaN
# 5     https://upload.wikimedia.org/wikipedia/en/thum...
# 17    https://upload.wikimedia.org/wikipedia/en/thum...
# 20    https://upload.wikimedia.org/wikipedia/en/thum...
# 25    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl[ipl['Team1'] == 'Rajasthan Royals'].shape[0] + ipl[ipl['Team2'] == 'Rajasthan Royals'].shape[0]
# Out:
# 192

# %%
import pandas as pd
import numpy as np
pd.read_csv('imdb-top-1000.csv')
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
df = pd.read_csv('movies.csv')
df.shape
# Out:
# (1629, 18)

# %%
df['actors'].iloc[0].split("|")[0]
# Out:
# 'Vicky Kaushal'

# %%
df['Lead_Role'] = df['actors'].str.split("|")[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['Lead_Role'] = df['actors'].str.split("|")[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)
#    4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
# ...

# %%
df.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
dropped_data = df.dropna()
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(dropped_data.shape[0]):
    dropped_data['actors'].iloc[i] = dropped_data['actors'].iloc[i].split("|")[0]

# %%
dropped_data.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...
